# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = np.random.poisson(4, 100000000)
fig=count, bins, ignored = plt.hist(s, 150,normed=True)
title("Distriducion de poisson")

# %%
a=arange(0,10,0.05)
b=exp(-a)
plt.plot(a,b)
title("Distriducion Gaussiana")

# %%
a=arange(-10,10,0.05)
b=exp(-a*a/2)
plt.plot(a,b)
title("Distriducion Gaussiana")
