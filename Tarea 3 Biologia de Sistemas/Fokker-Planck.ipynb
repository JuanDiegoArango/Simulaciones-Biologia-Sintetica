# %%
# %pylab inline
from scipy.misc import factorial
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['poisson', 'gamma']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def poisson(k,g,n):
    return pow((k/g),n)*exp(-k/g)/factorial(n)

# %%
def aproximacion(k,g,n):
    return pow((g*n+k),k/g-1)*exp(-n/2)

# %% [markdown]
# para todas las gráficas azul es aproximancion y rojo es poisson
#
# tasa de creacion =10
# tasa de destruccion=10

# %%
k=10.0
g=10.0

x=linspace(1,200,1000)
n=arange(1,200)
scatter(n,poisson(k,g,n),color="red")
plot(n,poisson(k,g,n),color="red")
plot(x,aproximacion(k,g,x)/norm(aproximacion(k,g,x)))
xlim(0,20)  
ylabel("probabilidad")
xlabel("numero de moleculas")

# %% [markdown]
# tasa de creacion = 0.1
# tasa de destruccion =2.0

# %%
k=0.1
g=2.0
x=linspace(1,200,1000)
n=arange(1,200)
scatter(n,poisson(k,g,n),color="red")
plot(n,poisson(k,g,n),color="red")
plot(x,aproximacion(k,g,x)/norm(aproximacion(k,g,x)))
xlim(0,20)  
ylabel("probabilidad")
xlabel("numero de moleculas")

# %% [markdown]
# tasa de creacion=10 tasa de destruccion=100

# %%
k=10.0
g=100.0
x=linspace(1,200,1000)
n=arange(1,200)
scatter(n,poisson(k,g,n),color="red")
plot(n,poisson(k,g,n),color="red")
plot(x,aproximacion(k,g,x)/norm(aproximacion(k,g,x)))
xlim(0,20)  
ylabel("probabilidad")
xlabel("numero de moleculas")

# %% [markdown]
# tasa de creacion = 5 tasa de destruccion =1

# %%
k=5.0
g=1.0
x=linspace(1,200,1000)
n=arange(1,200)
scatter(n,poisson(k,g,n),color="red")
plot(n,poisson(k,g,n),color="red")
plot(x,aproximacion(k,g,x)/norm(aproximacion(k,g,x)))
xlim(0,20) 
ylabel("probabilidad")
xlabel("numero de moleculas")
